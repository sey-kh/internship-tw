# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout, GRU, Bidirectional, LSTM
from keras.optimizers import SGD
import math
from sklearn.metrics import mean_squared_error
import keras
from sklearn.preprocessing import StandardScaler, PowerTransformer, MaxAbsScaler, Normalizer, RobustScaler, minmax_scale, QuantileTransformer
# Out:
# Using TensorFlow backend.

# %%
dataset = pd.read_csv('../input/historical_stock_prices.csv', index_col='date', parse_dates=['date'])

# %%
trainSet = dataset['2015':'2017'].sort_values(by=['ticker','date'])
testSet = dataset['2018':].sort_values(by=['ticker','date'])

# %%
trainSet.head()
# Out:
#            ticker       open      close   ...           low       high   volume
# date                                      ...
# 2015-01-02      A  41.180000  40.560001   ...     40.369999  41.310001  1529200
# 2015-01-05      A  40.320000  39.799999   ...     39.700001  40.459999  2041800
# 2015-01-06      A  39.810001  39.180000   ...     39.020000  40.020000  2080600
# 2015-01-07      A  39.520000  39.700001   ...     39.290001  39.810001  3359700
# 2015-01-08      A  40.240002  40.889999   ...     40.180000  40.980000  2116300
#
# [5 rows x 7 columns]

# %%
symbols = trainSet.ticker.unique()

# %%
symbols[:100]
# Out:
# array(['A', 'AA', 'AABA', 'AAL', 'AAME', 'AAN', 'AAOI', 'AAON', 'AAP',
#        'AAPL', 'AAT', 'AAV', 'AAWW', 'AAXJ', 'AAXN', 'AB', 'ABAC', 'ABAX',
#        'ABB', 'ABBV', 'ABC', 'ABCB', 'ABCD', 'ABDC', 'ABEO', 'ABEV',
#        'ABG', 'ABIL', 'ABIO', 'ABM', 'ABMD', 'ABR', 'ABT', 'ABTX', 'ABUS',
#        'ABX', 'AC', 'ACAD', 'ACBI', 'ACC', 'ACCO', 'ACER', 'ACET', 'ACGL',
#        'ACGLO', 'ACGLP', 'ACH', 'ACHC', 'ACHN', 'ACHV', 'ACIA', 'ACIU',
#        'ACIW', 'ACLS', 'ACM', 'ACMR', 'ACN', 'ACNB', 'ACOR', 'ACP',
#        'ACRE', 'ACRS', 'ACRX', 'ACSF', 'ACST', 'ACT', 'ACTG', 'ACWI',
#        'ACWX', 'ACXM', 'ADAP', 'ADBE', 'ADC', 'ADES', 'ADI', 'ADM',
#        'ADMA', 'ADMP', 'ADMS', 'ADNT', 'ADOM', 'ADP', 'ADRA', 'ADRD',
#        'ADRE', 'ADRO', 'ADRU', 'ADS', 'ADSK', 'ADSW', 'ADTN', 'ADUS',
#        'ADVM', 'ADX', 'ADXS', 'AEB', 'AED', 'AEE', 'AEG', 'AEGN'],
#       dtype=object)

# %%
timesteps = 60
def make_samples(
    data_1,
    s):
    
    stop_append = {}
    for i in prediction_intervals:
        stop_append.update({i:False}) 
    l = len(data_1)
    
    for i in range(timesteps, l):
        x_1 = data_1[i-timesteps: i, 0]
        for j in stop_append:
            if not stop_append[j]:
                if i+j-1 < l:
                    y = data_1[i+j-1,0]
                    y = y.reshape(-1,1)
                    x_1 = x_1.reshape(-1,1)
                    
                    sc = MinMaxScaler(feature_range=(0,1))
                    sc.partial_fit(x_1)
                    sc.partial_fit(y)
                    
                    train_set[s]['x_1'][j].append(sc.transform(x_1))
                    train_set[s]['y'][j].append(sc.transform(y))
                    
                    if y == data_1[l-1,0]:
                        stop_append[j] =True

# %%
# Define train_set
train_set = {}
prediction_intervals = [1,3,5,10]
for s in symbols:
    train_set.update({s:{
        'x_1':{},
        'y':{},
    }})
    for i in prediction_intervals:
        train_set[s]['x_1'][i] = []
        train_set[s]['y'][i] = []
            
    data_1 = trainSet.loc[trainSet['ticker'] == s][['adj_close']].values
        
    make_samples(
        data_1, 
        s)
    
    if s == 'AEGN':
        break

# %%
for s in train_set:
    for i in train_set[s]['y']:
        x_1 = train_set[s]['x_1'][i]
        y = train_set[s]['y'][i]
        train_set[s]['x_1'][i] = np.array(x_1)
        train_set[s]['y'][i] = np.array(y)

# %%
train_set['AAPL']['x_1'][1].shape
# Out:
# (695, 60, 1)

# %%
es = keras.callbacks.EarlyStopping(monitor='val_loss',patience=5, mode='min', restore_best_weights=True)

# %%
def make_gru_network():
    regressorGRU = Sequential()
    # First GRU layer with Dropout regularisation
    
    regressorGRU.add(GRU(units = 30, return_sequences = False, input_shape=(1,60), activation='tanh'))
    regressorGRU.add(Dropout(0.3))
    
    # The output layer
    regressorGRU.add(Dense(units=1))
    return regressorGRU

# %%
model = {}
model_history = {}
for i in prediction_intervals:
    model[i] = make_gru_network()
    model[i].compile(optimizer='rmsprop', loss='mean_squared_error')
    
    n_epoch = 100
    x_train = []
    y_train = []
    
    for s in train_set:
        for j in range (0, len(train_set[s]['x_1'][i])):
            x = [
                train_set[s]['x_1'][i][j],
            ]
            x_train.append(x)
        for j in train_set[s]['y'][i]:
            y_train.append(j)
    X_train, Y_train = np.array(x_train), np.array(y_train)
    X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], X_train.shape[2])
    Y_train = Y_train.reshape(Y_train.shape[0])
    
    print(X_train.shape, Y_train.shape)
    print('Fitting prediction interval {}  model'.format(i))
    model_history[i] = model[i].fit(X_train, Y_train, epochs = n_epoch, batch_size = 6000, 
                                    validation_split = 0.3,callbacks=[es])
# Out:
# (59622, 1, 60) (59622,)
# Fitting prediction interval 1  model
# Train on 41735 samples, validate on 17887 samples
# Epoch 1/100
# 41735/41735 [==============================] - 4s 85us/step - loss: 0.4586 - val_loss: 0.1338
# Epoch 2/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.1445 - val_loss: 0.0832
# Epoch 3/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.1072 - val_loss: 0.0609
# Epoch 4/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0863 - val_loss: 0.0478
# Epoch 5/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0721 - val_loss: 0.0401
# Epoch 6/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0628 - val_loss: 0.0351
# Epoch 7/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0539 - val_loss: 0.0326
# Epoch 8/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0507 - val_loss: 0.0288
# Epoch 9/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0440 - val_loss: 0.0299
# Epoch 10/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0419 - val_loss: 0.0256
# Epoch 11/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0394 - val_loss: 0.0273
# Epoch 12/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0368 - val_loss: 0.0241
# Epoch 13/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0358 - val_loss: 0.0258
# Epoch 14/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0340 - val_loss: 0.0219
# Epoch 15/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0335 - val_loss: 0.0254
# Epoch 16/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0315 - val_loss: 0.0212
# Epoch 17/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0326 - val_loss: 0.0229
# Epoch 18/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0296 - val_loss: 0.0202
# Epoch 19/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0310 - val_loss: 0.0253
# Epoch 20/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0287 - val_loss: 0.0192
# Epoch 21/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0298 - val_loss: 0.0240
# Epoch 22/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0279 - val_loss: 0.0188
# Epoch 23/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0287 - val_loss: 0.0248
# Epoch 24/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0276 - val_loss: 0.0182
# Epoch 25/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0284 - val_loss: 0.0225
# Epoch 26/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0267 - val_loss: 0.0179
# Epoch 27/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0269 - val_loss: 0.0234
# Epoch 28/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0270 - val_loss: 0.0176
# Epoch 29/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0265 - val_loss: 0.0214
# Epoch 30/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0266 - val_loss: 0.0176
# Epoch 31/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0259 - val_loss: 0.0205
# Epoch 32/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0260 - val_loss: 0.0172
# Epoch 33/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0252 - val_loss: 0.0211
# Epoch 34/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0257 - val_loss: 0.0166
# Epoch 35/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0246 - val_loss: 0.0218
# Epoch 36/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0256 - val_loss: 0.0163
# Epoch 37/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0242 - val_loss: 0.0195
# Epoch 38/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0249 - val_loss: 0.0166
# Epoch 39/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0250 - val_loss: 0.0180
# Epoch 40/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0241 - val_loss: 0.0170
# Epoch 41/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0247 - val_loss: 0.0173
# (59426, 1, 60) (59426,)
# Fitting prediction interval 3  model
# Train on 41598 samples, validate on 17828 samples
# Epoch 1/100
# 41598/41598 [==============================] - 4s 85us/step - loss: 0.4756 - val_loss: 0.1751
# Epoch 2/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.2179 - val_loss: 0.1220
# Epoch 3/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.1705 - val_loss: 0.0940
# Epoch 4/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.1391 - val_loss: 0.0762
# Epoch 5/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.1145 - val_loss: 0.0652
# Epoch 6/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0964 - val_loss: 0.0569
# Epoch 7/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0832 - val_loss: 0.0520
# Epoch 8/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0755 - val_loss: 0.0501
# Epoch 9/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0657 - val_loss: 0.0451
# Epoch 10/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0617 - val_loss: 0.0471
# Epoch 11/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0580 - val_loss: 0.0422
# Epoch 12/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0545 - val_loss: 0.0458
# Epoch 13/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0529 - val_loss: 0.0400
# Epoch 14/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0497 - val_loss: 0.0434
# Epoch 15/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0515 - val_loss: 0.0390
# Epoch 16/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0481 - val_loss: 0.0415
# Epoch 17/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0482 - val_loss: 0.0388
# Epoch 18/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0465 - val_loss: 0.0395
# Epoch 19/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0468 - val_loss: 0.0386
# Epoch 20/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0456 - val_loss: 0.0385
# Epoch 21/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0457 - val_loss: 0.0376
# Epoch 22/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0441 - val_loss: 0.0392
# Epoch 23/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0452 - val_loss: 0.0368
# Epoch 24/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0438 - val_loss: 0.0393
# Epoch 25/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0440 - val_loss: 0.0368
# Epoch 26/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0438 - val_loss: 0.0390
# Epoch 27/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0434 - val_loss: 0.0369
# Epoch 28/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0433 - val_loss: 0.0402
# Epoch 29/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0427 - val_loss: 0.0361
# Epoch 30/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0427 - val_loss: 0.0405
# Epoch 31/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0429 - val_loss: 0.0353
# Epoch 32/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0411 - val_loss: 0.0365
# Epoch 33/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0435 - val_loss: 0.0351
# Epoch 34/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0409 - val_loss: 0.0354
# Epoch 35/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0428 - val_loss: 0.0354
# Epoch 36/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0405 - val_loss: 0.0357
# Epoch 37/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0422 - val_loss: 0.0351
# Epoch 38/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0405 - val_loss: 0.0362
# (59230, 1, 60) (59230,)
# Fitting prediction interval 5  model
# Train on 41461 samples, validate on 17769 samples
# Epoch 1/100
# 41461/41461 [==============================] - 4s 90us/step - loss: 0.1747 - val_loss: 0.0804
# Epoch 2/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.1101 - val_loss: 0.0676
# Epoch 3/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0961 - val_loss: 0.0639
# Epoch 4/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0866 - val_loss: 0.0608
# Epoch 5/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0836 - val_loss: 0.0629
# Epoch 6/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0765 - val_loss: 0.0571
# Epoch 7/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0725 - val_loss: 0.0648
# Epoch 8/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0707 - val_loss: 0.0549
# Epoch 9/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0665 - val_loss: 0.0590
# Epoch 10/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0657 - val_loss: 0.0535
# Epoch 11/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0634 - val_loss: 0.0594
# Epoch 12/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0618 - val_loss: 0.0525
# Epoch 13/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0610 - val_loss: 0.0554
# Epoch 14/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0593 - val_loss: 0.0519
# Epoch 15/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0593 - val_loss: 0.0583
# Epoch 16/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0586 - val_loss: 0.0514
# Epoch 17/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0569 - val_loss: 0.0533
# Epoch 18/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0584 - val_loss: 0.0510
# Epoch 19/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0561 - val_loss: 0.0548
# Epoch 20/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0572 - val_loss: 0.0507
# Epoch 21/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0558 - val_loss: 0.0536
# Epoch 22/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0563 - val_loss: 0.0505
# Epoch 23/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0550 - val_loss: 0.0524
# Epoch 24/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0551 - val_loss: 0.0502
# Epoch 25/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0550 - val_loss: 0.0529
# Epoch 26/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0549 - val_loss: 0.0501
# Epoch 27/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0550 - val_loss: 0.0524
# Epoch 28/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0540 - val_loss: 0.0500
# Epoch 29/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0545 - val_loss: 0.0532
# Epoch 30/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0538 - val_loss: 0.0495
# Epoch 31/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0539 - val_loss: 0.0524
# Epoch 32/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0536 - val_loss: 0.0498
# Epoch 33/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0537 - val_loss: 0.0517
# Epoch 34/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0540 - val_loss: 0.0493
# Epoch 35/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0527 - val_loss: 0.0510
# Epoch 36/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0534 - val_loss: 0.0489
# Epoch 37/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0526 - val_loss: 0.0524
# Epoch 38/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0534 - val_loss: 0.0488
# Epoch 39/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0518 - val_loss: 0.0504
# Epoch 40/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0533 - val_loss: 0.0488
# Epoch 41/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0516 - val_loss: 0.0505
# Epoch 42/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0526 - val_loss: 0.0493
# Epoch 43/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0519 - val_loss: 0.0500
# Epoch 44/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0520 - val_loss: 0.0487
# Epoch 45/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0520 - val_loss: 0.0514
# Epoch 46/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0514 - val_loss: 0.0482
# Epoch 47/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0527 - val_loss: 0.0509
# Epoch 48/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0510 - val_loss: 0.0482
# Epoch 49/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0517 - val_loss: 0.0494
# Epoch 50/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0511 - val_loss: 0.0486
# Epoch 51/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0512 - val_loss: 0.0502
# Epoch 52/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0516 - val_loss: 0.0487
# Epoch 53/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0513 - val_loss: 0.0506
# (58740, 1, 60) (58740,)
# Fitting prediction interval 10  model
# Train on 41118 samples, validate on 17622 samples
# Epoch 1/100
# 41118/41118 [==============================] - 4s 94us/step - loss: 0.3446 - val_loss: 0.1771
# Epoch 2/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.1994 - val_loss: 0.1262
# Epoch 3/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.1552 - val_loss: 0.1051
# Epoch 4/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.1335 - val_loss: 0.0950
# Epoch 5/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.1195 - val_loss: 0.0890
# Epoch 6/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.1098 - val_loss: 0.0969
# Epoch 7/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.1047 - val_loss: 0.0811
# Epoch 8/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0972 - val_loss: 0.0819
# Epoch 9/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0929 - val_loss: 0.0773
# Epoch 10/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0911 - val_loss: 0.0796
# Epoch 11/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0868 - val_loss: 0.0750
# Epoch 12/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0856 - val_loss: 0.0785
# Epoch 13/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0829 - val_loss: 0.0736
# Epoch 14/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0820 - val_loss: 0.0737
# Epoch 15/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0815 - val_loss: 0.0751
# Epoch 16/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0790 - val_loss: 0.0737
# Epoch 17/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0799 - val_loss: 0.0723
# Epoch 18/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0781 - val_loss: 0.0732
# Epoch 19/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0775 - val_loss: 0.0724
# Epoch 20/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0778 - val_loss: 0.0737
# Epoch 21/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0763 - val_loss: 0.0719
# Epoch 22/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0770 - val_loss: 0.0722
# Epoch 23/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0761 - val_loss: 0.0716
# Epoch 24/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0767 - val_loss: 0.0723
# Epoch 25/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0758 - val_loss: 0.0707
# Epoch 26/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0745 - val_loss: 0.0709
# Epoch 27/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0761 - val_loss: 0.0732
# Epoch 28/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0744 - val_loss: 0.0716
# Epoch 29/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0747 - val_loss: 0.0702
# Epoch 30/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0748 - val_loss: 0.0742
# Epoch 31/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0740 - val_loss: 0.0701
# Epoch 32/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0748 - val_loss: 0.0747
# Epoch 33/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0736 - val_loss: 0.0697
# Epoch 34/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0734 - val_loss: 0.0753
# Epoch 35/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0745 - val_loss: 0.0696
# Epoch 36/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0733 - val_loss: 0.0728
# Epoch 37/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0735 - val_loss: 0.0695
# Epoch 38/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0741 - val_loss: 0.0735
# Epoch 39/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0733 - val_loss: 0.0693
# Epoch 40/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0726 - val_loss: 0.0725
# Epoch 41/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0732 - val_loss: 0.0691
# Epoch 42/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0733 - val_loss: 0.0707
# Epoch 43/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0728 - val_loss: 0.0692
# Epoch 44/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0726 - val_loss: 0.0743
# Epoch 45/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0733 - val_loss: 0.0691
# Epoch 46/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0717 - val_loss: 0.0697
# Epoch 47/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0721 - val_loss: 0.0705
# Epoch 48/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0729 - val_loss: 0.0695
# Epoch 49/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0719 - val_loss: 0.0690
# Epoch 50/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0723 - val_loss: 0.0702
# Epoch 51/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0718 - val_loss: 0.0687
# Epoch 52/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0718 - val_loss: 0.0710
# Epoch 53/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0717 - val_loss: 0.0685
# Epoch 54/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0720 - val_loss: 0.0715
# Epoch 55/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0709 - val_loss: 0.0684
# Epoch 56/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0724 - val_loss: 0.0710
# Epoch 57/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0712 - val_loss: 0.0707
# Epoch 58/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0718 - val_loss: 0.0683
# Epoch 59/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0716 - val_loss: 0.0703
# Epoch 60/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0711 - val_loss: 0.0682
# Epoch 61/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0715 - val_loss: 0.0704
# Epoch 62/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0710 - val_loss: 0.0681
# Epoch 63/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0711 - val_loss: 0.0731
# Epoch 64/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0714 - val_loss: 0.0680
# Epoch 65/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0703 - val_loss: 0.0685
# Epoch 66/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0712 - val_loss: 0.0730
# Epoch 67/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0709 - val_loss: 0.0679
# Epoch 68/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0706 - val_loss: 0.0693
# Epoch 69/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0704 - val_loss: 0.0679
# Epoch 70/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0705 - val_loss: 0.0679
# Epoch 71/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0703 - val_loss: 0.0742
# Epoch 72/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0705 - val_loss: 0.0677
# Epoch 73/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0698 - val_loss: 0.0723
# Epoch 74/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0707 - val_loss: 0.0677
# Epoch 75/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0701 - val_loss: 0.0731
# Epoch 76/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0703 - val_loss: 0.0676
# Epoch 77/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0696 - val_loss: 0.0700
# Epoch 78/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0711 - val_loss: 0.0675
# Epoch 79/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0700 - val_loss: 0.0687
# Epoch 80/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0693 - val_loss: 0.0694
# Epoch 81/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0706 - val_loss: 0.0674
# Epoch 82/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0692 - val_loss: 0.0697
# Epoch 83/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0703 - val_loss: 0.0674
# Epoch 84/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0691 - val_loss: 0.0673
# Epoch 85/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0705 - val_loss: 0.0685
# Epoch 86/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0692 - val_loss: 0.0729
# Epoch 87/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0701 - val_loss: 0.0672
# Epoch 88/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0688 - val_loss: 0.0682
# Epoch 89/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0702 - val_loss: 0.0707
# Epoch 90/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0689 - val_loss: 0.0673
# Epoch 91/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0686 - val_loss: 0.0706
# Epoch 92/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0698 - val_loss: 0.0670
# Epoch 93/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0685 - val_loss: 0.0672
# Epoch 94/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0698 - val_loss: 0.0670
# Epoch 95/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0686 - val_loss: 0.0676
# Epoch 96/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0696 - val_loss: 0.0669
# Epoch 97/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0684 - val_loss: 0.0677
# Epoch 98/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0689 - val_loss: 0.0668
# Epoch 99/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0693 - val_loss: 0.0705
# Epoch 100/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0693 - val_loss: 0.0667

# %%
# Calculate Mean squared_error #
def return_mse(test,predicted):
    mse = mean_squared_error(test, predicted)
    return mse

# %%
# Plotting graph
def plotting_graph(y_test, y_pred, ticker, des):
    plt.plot(y_test, color='green', label='Actual adj_close value')
    plt.plot(y_pred, color='red', label='Predicted adj_close value')
    plt.title('Prediction of {} on {}'.format(ticker, des))
    plt.xlabel('Time steps')
    plt.ylabel('adj_close value')
    plt.legend()
    plt.show()

# %%
def make_test_data(s):
    scaler = {s:{}}
    test_set = {s:{}}
    test_set.update({s:{
            'x_1':{},
            'y':{},
        }})
    for i in prediction_intervals:
            test_set[s]['x_1'][i] = []
            test_set[s]['y'][i] = []
            scaler[s][i] = []

    data_1 = testSet.loc[testSet['ticker'] == s][['adj_close']].values
    
    stop_append = {}
    for i in prediction_intervals:
        stop_append.update({i:False}) 
    l = len(data_1)

    for i in range(timesteps, l):
        x_1 = data_1[i-timesteps: i, 0]
        for j in stop_append:
            if not stop_append[j]:
                if i+j-1 < l:
                    y = data_1[i+j-1,0]
                    y = y.reshape(-1,1)
                    x_1 = x_1.reshape(-1,1)
                    
                    sc = MinMaxScaler(feature_range=(0,1))
                    sc.partial_fit(x_1)
                    sc.partial_fit(y)
                    scaler[s][j].append(sc)
                    
                    test_set[s]['x_1'][j].append(sc.transform(x_1))
                    test_set[s]['y'][j].append(y)
                    
                    if y == data_1[l-1,0]:
                        stop_append[j] =True
                    
    return test_set, scaler

# %%
def make_prediction(data, s, scaler):
    mse_val = {}
    y_true_val = {}
    y_pred_val = {}
    
    for i in prediction_intervals:
        x_test = []
        for j in range (0, len(data[s]['x_1'][i])):
            x = [
                data[s]['x_1'][i][j],
            ]
            x_test.append(x)

        X_test = np.array(x_test)
        X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], X_test.shape[2])
        
        result = model[i].predict(X_test)
        
        y_pred = []
        for j in range(0,len(result)):
            y = result[j]
            y = y.reshape(-1,1)
            k = scaler[s][i][j].inverse_transform(y)
            y_pred.append(k[0][0])
                    
        y_test = data[s]['y'][i]
        y_true = np.array(y_test)
        y_true = y_true.reshape(y_true.shape[0])
    
        y_true_val[i] = y_true
        y_pred_val[i] = y_pred

        mse_val[i] = return_mse(y_true, y_pred) 
    return y_true_val, y_pred_val, mse_val

# %%
s = 'AAPL'
data, sc = make_test_data(s)
y_true_val, y_pred_val, mse_val = make_prediction(data, s, sc)

for i in mse_val:
    print('Test Set -> MSE of {} inveral {}: {}'.format(s, i, mse_val[i]))
# Out:
# Test Set -> MSE of AAPL inveral 1: 10.237787958671563
# Test Set -> MSE of AAPL inveral 3: 30.912441707702907
# Test Set -> MSE of AAPL inveral 5: 43.13389565292561
# Test Set -> MSE of AAPL inveral 10: 73.30698038195285

# %%
for i in [1,10]:
    plotting_graph(y_true_val[i], y_pred_val[i], s, 'Test Set interval {}'.format(i))

# %% [markdown]
# # MSE of 5 symbols

# %%
test_symbols = ['A','AAPL','ABAX','ACIU','ADUS']

# %%
all_mse = {}
for s in test_symbols:
    all_mse[s] = {}
    data, sc = make_test_data(s)
    y_true_val, y_pred_val, mse_val = make_prediction(data, s, sc)
    for i in prediction_intervals:
        all_mse[s][i] = mse_val[i]
        all_mse[s][i] = mse_val[i]

# %%
all_mse_1 = []
all_mse_10 = []
for s in all_mse:
    all_mse_1.append(round(all_mse[s][1], 3))
    all_mse_10.append(round(all_mse[s][10], 3))

# %%
all_mse_1
# Out:
# [1.415, 10.238, 4.777, 1.445, 2.358]

# %%
all_mse_10
# Out:
# [4.043, 73.307, 25.308, 6.523, 13.365]
