# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout, GRU, Bidirectional, LSTM
from keras.optimizers import SGD
import math
from sklearn.metrics import mean_squared_error
import keras
from sklearn.preprocessing import StandardScaler, PowerTransformer, MaxAbsScaler, Normalizer, RobustScaler, minmax_scale, QuantileTransformer
# Out:
# Using TensorFlow backend.

# %%
dataset = pd.read_csv('../input/historical_stock_prices.csv', index_col='date', parse_dates=['date'])

# %%
trainSet = dataset['2015':'2017'].sort_values(by=['ticker','date'])
testSet = dataset['2018':].sort_values(by=['ticker','date'])

# %%
trainSet.head()
# Out:
#            ticker       open      close   ...           low       high   volume
# date                                      ...
# 2015-01-02      A  41.180000  40.560001   ...     40.369999  41.310001  1529200
# 2015-01-05      A  40.320000  39.799999   ...     39.700001  40.459999  2041800
# 2015-01-06      A  39.810001  39.180000   ...     39.020000  40.020000  2080600
# 2015-01-07      A  39.520000  39.700001   ...     39.290001  39.810001  3359700
# 2015-01-08      A  40.240002  40.889999   ...     40.180000  40.980000  2116300
#
# [5 rows x 7 columns]

# %%
symbols = trainSet.ticker.unique()

# %%
symbols[:100]

# %%
timesteps = 60
def make_samples(
    data_1,
    data_2,
    s):
    
    stop_append = {}
    for i in prediction_intervals:
        stop_append.update({i:False}) 
    l = len(data_1)
    for i in range(timesteps, l):
        x_1 = data_1[i-timesteps: i, 0]
        x_2 = data_2[i-timesteps:i, 0]

        for j in stop_append:
            if not stop_append[j]:
                if i+j-1 < l:
                    y = data_1[i+j-1,0]
                    y = y.reshape(-1,1)
                    x_1 = x_1.reshape(-1,1)
                    x_2 = x_2.reshape(-1,1)                    
                    sc = MinMaxScaler(feature_range=(0,1))
                    sc.partial_fit(x_1)
                    sc.partial_fit(y)
                    
                    train_set[s]['x_1'][j].append(sc.transform(x_1))
                    train_set[s]['y'][j].append(sc.transform(y))
                    sc = MinMaxScaler(feature_range=(0,1))
                    train_set[s]['x_2'][j].append(sc.fit_transform(x_2))
                    
                    if y == data_1[l-1,0]:
                        stop_append[j] =True

# %%
# Define train_set
train_set = {}
prediction_intervals = [1,3,5,10]
for s in symbols:
    train_set.update({s:{
        'x_1':{},
        'x_2':{},
        'y':{},
    }})
    for i in prediction_intervals:
        train_set[s]['x_1'][i] = []
        train_set[s]['x_2'][i] = []
        train_set[s]['y'][i] = []
    
    data_1 = trainSet.loc[trainSet['ticker'] == s][['adj_close']].values
    data_2 = trainSet.loc[trainSet['ticker'] == s][['volume']].values
  
    make_samples(
        data_1, 
        data_2, 
        s)
    
    if s == 'AEGN':
        break

# %%
for s in train_set:
    for i in train_set[s]['y']:
        x_1 = train_set[s]['x_1'][i]
        x_2 = train_set[s]['x_2'][i]
        y = train_set[s]['y'][i]
        train_set[s]['x_1'][i] = np.array(x_1)
        train_set[s]['x_2'][i] = np.array(x_2)
        train_set[s]['y'][i] = np.array(y)

# %%
train_set['AAPL']['x_1'][1].shape
# Out:
# (695, 60, 1)

# %%
es = keras.callbacks.EarlyStopping(monitor='val_loss',patience=5, mode='min', restore_best_weights=True)

# %%
def make_gru_network():
    regressorGRU = Sequential()
    # First GRU layer with Dropout regularisation
    
    regressorGRU.add(GRU(units = 30, return_sequences = False, input_shape=(2,60), activation='tanh'))
    regressorGRU.add(Dropout(0.3))
    
    # The output layer
    regressorGRU.add(Dense(units=1))
    return regressorGRU

# %%
model = {}
model_history = {}
for i in prediction_intervals:
    model[i] = make_gru_network()
    model[i].compile(optimizer='rmsprop', loss='mean_squared_error')
    
    n_epoch = 100
    x_train = []
    y_train = []
    
    for s in train_set:
        for j in range (0, len(train_set[s]['x_1'][i])):
            x = [
                train_set[s]['x_1'][i][j],
                train_set[s]['x_2'][i][j],
            ]
            x_train.append(x)
        for j in train_set[s]['y'][i]:
            y_train.append(j)
    X_train, Y_train = np.array(x_train), np.array(y_train)
    X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], X_train.shape[2])
    Y_train = Y_train.reshape(Y_train.shape[0])
    
    print(X_train.shape, Y_train.shape)
    print('Fitting prediction interval {}  model'.format(i))
    model_history[i] = model[i].fit(X_train, Y_train, epochs = n_epoch, batch_size = 6000, 
                                    validation_split = 0.3,callbacks=[es])
# Out:
# (59622, 2, 60) (59622,)
# Fitting prediction interval 1  model
# Train on 41735 samples, validate on 17887 samples
# Epoch 1/100
# 41735/41735 [==============================] - 2s 47us/step - loss: 0.3115 - val_loss: 0.1127
# Epoch 2/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.1278 - val_loss: 0.0923
# Epoch 3/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.1071 - val_loss: 0.0780
# Epoch 4/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0915 - val_loss: 0.0678
# Epoch 5/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0805 - val_loss: 0.0604
# Epoch 6/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0731 - val_loss: 0.0644
# Epoch 7/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0704 - val_loss: 0.0513
# Epoch 8/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0616 - val_loss: 0.0545
# Epoch 9/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0611 - val_loss: 0.0451
# Epoch 10/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0534 - val_loss: 0.0435
# Epoch 11/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0557 - val_loss: 0.0402
# Epoch 12/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0485 - val_loss: 0.0395
# Epoch 13/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0503 - val_loss: 0.0365
# Epoch 14/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0449 - val_loss: 0.0388
# Epoch 15/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0457 - val_loss: 0.0338
# Epoch 16/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0430 - val_loss: 0.0372
# Epoch 17/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0420 - val_loss: 0.0308
# Epoch 18/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0398 - val_loss: 0.0365
# Epoch 19/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0407 - val_loss: 0.0289
# Epoch 20/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0370 - val_loss: 0.0342
# Epoch 21/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0391 - val_loss: 0.0273
# Epoch 22/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0353 - val_loss: 0.0289
# Epoch 23/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0366 - val_loss: 0.0260
# Epoch 24/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0339 - val_loss: 0.0311
# Epoch 25/100
# 41735/41735 [==============================] - 0s 3us/step - loss: 0.0354 - val_loss: 0.0244
# Epoch 26/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0337 - val_loss: 0.0296
# Epoch 27/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0333 - val_loss: 0.0240
# Epoch 28/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0330 - val_loss: 0.0279
# Epoch 29/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0324 - val_loss: 0.0239
# Epoch 30/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0316 - val_loss: 0.0250
# Epoch 31/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0317 - val_loss: 0.0226
# Epoch 32/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0307 - val_loss: 0.0249
# Epoch 33/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0308 - val_loss: 0.0227
# Epoch 34/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0303 - val_loss: 0.0236
# Epoch 35/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0293 - val_loss: 0.0235
# Epoch 36/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0299 - val_loss: 0.0214
# Epoch 37/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0288 - val_loss: 0.0231
# Epoch 38/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0292 - val_loss: 0.0219
# Epoch 39/100
# 41735/41735 [==============================] - 0s 3us/step - loss: 0.0281 - val_loss: 0.0208
# Epoch 40/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0287 - val_loss: 0.0219
# Epoch 41/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0274 - val_loss: 0.0204
# Epoch 42/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0281 - val_loss: 0.0223
# Epoch 43/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0274 - val_loss: 0.0199
# Epoch 44/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0278 - val_loss: 0.0220
# Epoch 45/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0265 - val_loss: 0.0196
# Epoch 46/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0269 - val_loss: 0.0225
# Epoch 47/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0264 - val_loss: 0.0187
# Epoch 48/100
# 41735/41735 [==============================] - 0s 3us/step - loss: 0.0268 - val_loss: 0.0214
# Epoch 49/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0260 - val_loss: 0.0189
# Epoch 50/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0256 - val_loss: 0.0215
# Epoch 51/100
# 41735/41735 [==============================] - 0s 3us/step - loss: 0.0260 - val_loss: 0.0185
# Epoch 52/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0263 - val_loss: 0.0202
# Epoch 53/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0253 - val_loss: 0.0188
# Epoch 54/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0255 - val_loss: 0.0202
# Epoch 55/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0257 - val_loss: 0.0179
# Epoch 56/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0242 - val_loss: 0.0204
# Epoch 57/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0255 - val_loss: 0.0181
# Epoch 58/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0240 - val_loss: 0.0197
# Epoch 59/100
# 41735/41735 [==============================] - 0s 3us/step - loss: 0.0252 - val_loss: 0.0173
# Epoch 60/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0238 - val_loss: 0.0196
# Epoch 61/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0249 - val_loss: 0.0179
# Epoch 62/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0240 - val_loss: 0.0182
# Epoch 63/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0239 - val_loss: 0.0172
# Epoch 64/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0240 - val_loss: 0.0188
# Epoch 65/100
# 41735/41735 [==============================] - 0s 3us/step - loss: 0.0239 - val_loss: 0.0170
# Epoch 66/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0234 - val_loss: 0.0193
# Epoch 67/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0237 - val_loss: 0.0167
# Epoch 68/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0231 - val_loss: 0.0189
# Epoch 69/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0235 - val_loss: 0.0163
# Epoch 70/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0229 - val_loss: 0.0196
# Epoch 71/100
# 41735/41735 [==============================] - 0s 3us/step - loss: 0.0234 - val_loss: 0.0164
# Epoch 72/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0230 - val_loss: 0.0180
# Epoch 73/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0225 - val_loss: 0.0159
# Epoch 74/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0232 - val_loss: 0.0182
# Epoch 75/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0222 - val_loss: 0.0165
# Epoch 76/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0230 - val_loss: 0.0171
# Epoch 77/100
# 41735/41735 [==============================] - 0s 3us/step - loss: 0.0219 - val_loss: 0.0165
# Epoch 78/100
# 41735/41735 [==============================] - 0s 2us/step - loss: 0.0228 - val_loss: 0.0170
# (59426, 2, 60) (59426,)
# Fitting prediction interval 3  model
# Train on 41598 samples, validate on 17828 samples
# Epoch 1/100
# 41598/41598 [==============================] - 1s 17us/step - loss: 0.2507 - val_loss: 0.1211
# Epoch 2/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.1434 - val_loss: 0.0970
# Epoch 3/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.1177 - val_loss: 0.0823
# Epoch 4/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.1012 - val_loss: 0.0745
# Epoch 5/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0916 - val_loss: 0.0718
# Epoch 6/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0857 - val_loss: 0.0672
# Epoch 7/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0789 - val_loss: 0.0619
# Epoch 8/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0745 - val_loss: 0.0650
# Epoch 9/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0714 - val_loss: 0.0563
# Epoch 10/100
# 41598/41598 [==============================] - 0s 3us/step - loss: 0.0681 - val_loss: 0.0577
# Epoch 11/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0655 - val_loss: 0.0528
# Epoch 12/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0615 - val_loss: 0.0542
# Epoch 13/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0602 - val_loss: 0.0506
# Epoch 14/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0584 - val_loss: 0.0504
# Epoch 15/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0567 - val_loss: 0.0473
# Epoch 16/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0548 - val_loss: 0.0500
# Epoch 17/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0532 - val_loss: 0.0443
# Epoch 18/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0539 - val_loss: 0.0498
# Epoch 19/100
# 41598/41598 [==============================] - 0s 3us/step - loss: 0.0505 - val_loss: 0.0423
# Epoch 20/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0504 - val_loss: 0.0484
# Epoch 21/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0503 - val_loss: 0.0412
# Epoch 22/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0478 - val_loss: 0.0452
# Epoch 23/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0488 - val_loss: 0.0401
# Epoch 24/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0465 - val_loss: 0.0429
# Epoch 25/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0473 - val_loss: 0.0397
# Epoch 26/100
# 41598/41598 [==============================] - 0s 3us/step - loss: 0.0464 - val_loss: 0.0426
# Epoch 27/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0461 - val_loss: 0.0382
# Epoch 28/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0444 - val_loss: 0.0417
# Epoch 29/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0455 - val_loss: 0.0375
# Epoch 30/100
# 41598/41598 [==============================] - 0s 3us/step - loss: 0.0445 - val_loss: 0.0423
# Epoch 31/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0444 - val_loss: 0.0370
# Epoch 32/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0432 - val_loss: 0.0409
# Epoch 33/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0439 - val_loss: 0.0367
# Epoch 34/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0424 - val_loss: 0.0405
# Epoch 35/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0432 - val_loss: 0.0364
# Epoch 36/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0423 - val_loss: 0.0387
# Epoch 37/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0425 - val_loss: 0.0358
# Epoch 38/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0414 - val_loss: 0.0402
# Epoch 39/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0418 - val_loss: 0.0352
# Epoch 40/100
# 41598/41598 [==============================] - 0s 3us/step - loss: 0.0420 - val_loss: 0.0368
# Epoch 41/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0406 - val_loss: 0.0358
# Epoch 42/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0414 - val_loss: 0.0359
# Epoch 43/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0396 - val_loss: 0.0351
# Epoch 44/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0419 - val_loss: 0.0366
# Epoch 45/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0393 - val_loss: 0.0350
# Epoch 46/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0413 - val_loss: 0.0373
# Epoch 47/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0396 - val_loss: 0.0344
# Epoch 48/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0397 - val_loss: 0.0369
# Epoch 49/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0396 - val_loss: 0.0340
# Epoch 50/100
# 41598/41598 [==============================] - 0s 3us/step - loss: 0.0402 - val_loss: 0.0372
# Epoch 51/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0389 - val_loss: 0.0337
# Epoch 52/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0399 - val_loss: 0.0361
# Epoch 53/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0391 - val_loss: 0.0338
# Epoch 54/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0392 - val_loss: 0.0366
# Epoch 55/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0382 - val_loss: 0.0339
# Epoch 56/100
# 41598/41598 [==============================] - 0s 2us/step - loss: 0.0394 - val_loss: 0.0357
# (59230, 2, 60) (59230,)
# Fitting prediction interval 5  model
# Train on 41461 samples, validate on 17769 samples
# Epoch 1/100
# 41461/41461 [==============================] - 1s 19us/step - loss: 0.2198 - val_loss: 0.1179
# Epoch 2/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.1427 - val_loss: 0.1021
# Epoch 3/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.1217 - val_loss: 0.0894
# Epoch 4/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.1068 - val_loss: 0.0821
# Epoch 5/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.1001 - val_loss: 0.0873
# Epoch 6/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0934 - val_loss: 0.0751
# Epoch 7/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0867 - val_loss: 0.0848
# Epoch 8/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0860 - val_loss: 0.0698
# Epoch 9/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0808 - val_loss: 0.0739
# Epoch 10/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0777 - val_loss: 0.0662
# Epoch 11/100
# 41461/41461 [==============================] - 0s 3us/step - loss: 0.0741 - val_loss: 0.0701
# Epoch 12/100
# 41461/41461 [==============================] - 0s 3us/step - loss: 0.0762 - val_loss: 0.0629
# Epoch 13/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0702 - val_loss: 0.0620
# Epoch 14/100
# 41461/41461 [==============================] - 0s 3us/step - loss: 0.0711 - val_loss: 0.0620
# Epoch 15/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0678 - val_loss: 0.0613
# Epoch 16/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0671 - val_loss: 0.0596
# Epoch 17/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0657 - val_loss: 0.0620
# Epoch 18/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0652 - val_loss: 0.0572
# Epoch 19/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0646 - val_loss: 0.0594
# Epoch 20/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0630 - val_loss: 0.0564
# Epoch 21/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0625 - val_loss: 0.0585
# Epoch 22/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0612 - val_loss: 0.0554
# Epoch 23/100
# 41461/41461 [==============================] - 0s 3us/step - loss: 0.0619 - val_loss: 0.0554
# Epoch 24/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0608 - val_loss: 0.0542
# Epoch 25/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0591 - val_loss: 0.0575
# Epoch 26/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0594 - val_loss: 0.0530
# Epoch 27/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0584 - val_loss: 0.0572
# Epoch 28/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0587 - val_loss: 0.0524
# Epoch 29/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0577 - val_loss: 0.0552
# Epoch 30/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0566 - val_loss: 0.0519
# Epoch 31/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0571 - val_loss: 0.0559
# Epoch 32/100
# 41461/41461 [==============================] - 0s 3us/step - loss: 0.0565 - val_loss: 0.0512
# Epoch 33/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0564 - val_loss: 0.0528
# Epoch 34/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0556 - val_loss: 0.0529
# Epoch 35/100
# 41461/41461 [==============================] - 0s 3us/step - loss: 0.0564 - val_loss: 0.0512
# Epoch 36/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0537 - val_loss: 0.0510
# Epoch 37/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0576 - val_loss: 0.0504
# Epoch 38/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0543 - val_loss: 0.0514
# Epoch 39/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0555 - val_loss: 0.0510
# Epoch 40/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0543 - val_loss: 0.0514
# Epoch 41/100
# 41461/41461 [==============================] - 0s 2us/step - loss: 0.0545 - val_loss: 0.0514
# Epoch 42/100
# 41461/41461 [==============================] - 0s 3us/step - loss: 0.0543 - val_loss: 0.0508
# (58740, 2, 60) (58740,)
# Fitting prediction interval 10  model
# Train on 41118 samples, validate on 17622 samples
# Epoch 1/100
# 41118/41118 [==============================] - 1s 24us/step - loss: 0.1914 - val_loss: 0.1221
# Epoch 2/100
# 41118/41118 [==============================] - 0s 3us/step - loss: 0.1393 - val_loss: 0.1030
# Epoch 3/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.1242 - val_loss: 0.1005
# Epoch 4/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.1103 - val_loss: 0.0910
# Epoch 5/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.1078 - val_loss: 0.0952
# Epoch 6/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.1012 - val_loss: 0.0862
# Epoch 7/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0993 - val_loss: 0.0906
# Epoch 8/100
# 41118/41118 [==============================] - 0s 3us/step - loss: 0.0958 - val_loss: 0.0831
# Epoch 9/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0931 - val_loss: 0.0834
# Epoch 10/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0916 - val_loss: 0.0802
# Epoch 11/100
# 41118/41118 [==============================] - 0s 3us/step - loss: 0.0873 - val_loss: 0.0793
# Epoch 12/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0857 - val_loss: 0.0932
# Epoch 13/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0872 - val_loss: 0.0765
# Epoch 14/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0826 - val_loss: 0.0763
# Epoch 15/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0843 - val_loss: 0.0781
# Epoch 16/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0801 - val_loss: 0.0745
# Epoch 17/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0806 - val_loss: 0.0826
# Epoch 18/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0800 - val_loss: 0.0743
# Epoch 19/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0781 - val_loss: 0.0816
# Epoch 20/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0799 - val_loss: 0.0727
# Epoch 21/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0777 - val_loss: 0.0766
# Epoch 22/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0785 - val_loss: 0.0722
# Epoch 23/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0762 - val_loss: 0.0751
# Epoch 24/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0772 - val_loss: 0.0718
# Epoch 25/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0760 - val_loss: 0.0742
# Epoch 26/100
# 41118/41118 [==============================] - 0s 3us/step - loss: 0.0763 - val_loss: 0.0719
# Epoch 27/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0750 - val_loss: 0.0731
# Epoch 28/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0755 - val_loss: 0.0711
# Epoch 29/100
# 41118/41118 [==============================] - 0s 3us/step - loss: 0.0748 - val_loss: 0.0733
# Epoch 30/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0741 - val_loss: 0.0709
# Epoch 31/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0760 - val_loss: 0.0725
# Epoch 32/100
# 41118/41118 [==============================] - 0s 3us/step - loss: 0.0731 - val_loss: 0.0717
# Epoch 33/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0747 - val_loss: 0.0707
# Epoch 34/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0730 - val_loss: 0.0701
# Epoch 35/100
# 41118/41118 [==============================] - 0s 3us/step - loss: 0.0746 - val_loss: 0.0751
# Epoch 36/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0734 - val_loss: 0.0700
# Epoch 37/100
# 41118/41118 [==============================] - ETA: 0s - loss: 0.072 - 0s 2us/step - loss: 0.0729 - val_loss: 0.0735
# Epoch 38/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0732 - val_loss: 0.0698
# Epoch 39/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0725 - val_loss: 0.0705
# Epoch 40/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0732 - val_loss: 0.0702
# Epoch 41/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0728 - val_loss: 0.0709
# Epoch 42/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0723 - val_loss: 0.0695
# Epoch 43/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0727 - val_loss: 0.0722
# Epoch 44/100
# 41118/41118 [==============================] - 0s 3us/step - loss: 0.0720 - val_loss: 0.0694
# Epoch 45/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0725 - val_loss: 0.0693
# Epoch 46/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0708 - val_loss: 0.0731
# Epoch 47/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0721 - val_loss: 0.0692
# Epoch 48/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0706 - val_loss: 0.0747
# Epoch 49/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0724 - val_loss: 0.0691
# Epoch 50/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0711 - val_loss: 0.0721
# Epoch 51/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0717 - val_loss: 0.0689
# Epoch 52/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0709 - val_loss: 0.0713
# Epoch 53/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0708 - val_loss: 0.0685
# Epoch 54/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0707 - val_loss: 0.0748
# Epoch 55/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0705 - val_loss: 0.0685
# Epoch 56/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0703 - val_loss: 0.0743
# Epoch 57/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0708 - val_loss: 0.0683
# Epoch 58/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0694 - val_loss: 0.0685
# Epoch 59/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0715 - val_loss: 0.0711
# Epoch 60/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0697 - val_loss: 0.0682
# Epoch 61/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0703 - val_loss: 0.0733
# Epoch 62/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0703 - val_loss: 0.0681
# Epoch 63/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0700 - val_loss: 0.0738
# Epoch 64/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0698 - val_loss: 0.0680
# Epoch 65/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0692 - val_loss: 0.0718
# Epoch 66/100
# 41118/41118 [==============================] - 0s 3us/step - loss: 0.0704 - val_loss: 0.0678
# Epoch 67/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0691 - val_loss: 0.0723
# Epoch 68/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0698 - val_loss: 0.0678
# Epoch 69/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0694 - val_loss: 0.0711
# Epoch 70/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0695 - val_loss: 0.0677
# Epoch 71/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0690 - val_loss: 0.0698
# Epoch 72/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0695 - val_loss: 0.0677
# Epoch 73/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0691 - val_loss: 0.0710
# Epoch 74/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0685 - val_loss: 0.0680
# Epoch 75/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0684 - val_loss: 0.0675
# Epoch 76/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0691 - val_loss: 0.0690
# Epoch 77/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0678 - val_loss: 0.0673
# Epoch 78/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0689 - val_loss: 0.0685
# Epoch 79/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0684 - val_loss: 0.0676
# Epoch 80/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0681 - val_loss: 0.0695
# Epoch 81/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0682 - val_loss: 0.0671
# Epoch 82/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0685 - val_loss: 0.0691
# Epoch 83/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0673 - val_loss: 0.0671
# Epoch 84/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0690 - val_loss: 0.0698
# Epoch 85/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0677 - val_loss: 0.0671
# Epoch 86/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0678 - val_loss: 0.0677
# Epoch 87/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0672 - val_loss: 0.0678
# Epoch 88/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0686 - val_loss: 0.0669
# Epoch 89/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0671 - val_loss: 0.0669
# Epoch 90/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0669 - val_loss: 0.0697
# Epoch 91/100
# 41118/41118 [==============================] - 0s 3us/step - loss: 0.0686 - val_loss: 0.0667
# Epoch 92/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0672 - val_loss: 0.0683
# Epoch 93/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0673 - val_loss: 0.0669
# Epoch 94/100
# 41118/41118 [==============================] - 0s 3us/step - loss: 0.0676 - val_loss: 0.0690
# Epoch 95/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0677 - val_loss: 0.0667
# Epoch 96/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0671 - val_loss: 0.0693
# Epoch 97/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0666 - val_loss: 0.0665
# Epoch 98/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0680 - val_loss: 0.0695
# Epoch 99/100
# 41118/41118 [==============================] - 0s 2us/step - loss: 0.0665 - val_loss: 0.0665
# Epoch 100/100
# 41118/41118 [==============================] - 0s 3us/step - loss: 0.0677 - val_loss: 0.0686

# %%
for i in prediction_intervals:
    plt.plot(model_history[i].history['val_loss'])
plt.title('Validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Interval 1', 'Interval 3', 'Interval 5', 'Interval 10'], loc='upper right')
plt.show()

# %%
for i in [1,10]:
    plt.plot(model_history[i].history['val_loss'])
    plt.plot(model_history[i].history['loss'])
    plt.title('Model Loss Interval {}'.format(i))
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['val_loss', 'loss'], loc='upper right')
    plt.show()

# %%
# Calculate Mean squared_error #
def return_mse(test,predicted):
    mse = mean_squared_error(test, predicted)
    return mse

# %%
# Plotting graph
def plotting_graph(y_test, y_pred, ticker, des):
    plt.plot(y_test, color='green', label='Actual adj_close value')
    plt.plot(y_pred, color='red', label='Predicted adj_close value')
    plt.title('Prediction of {} on {}'.format(ticker, des))
    plt.xlabel('Time steps')
    plt.ylabel('adj_close value')
    plt.legend()
    plt.show()

# %%
def make_test_data(s):
    scaler = {s:{}}
    test_set = {s:{}}
    test_set.update({s:{
            'x_1':{},
            'x_2':{},
            'y':{},
        }})
    for i in prediction_intervals:
            test_set[s]['x_1'][i] = []
            test_set[s]['x_2'][i] = []
            test_set[s]['y'][i] = []
            scaler[s][i] = []

    data_1 = testSet.loc[testSet['ticker'] == s][['adj_close']].values
    data_2 = testSet.loc[testSet['ticker'] == s][['volume']].values

    stop_append = {}
    for i in prediction_intervals:
        stop_append.update({i:False}) 
    l = len(data_1)
    for i in range(timesteps, l):
        x_1 = data_1[i-timesteps: i, 0]
        x_2 = data_2[i-timesteps:i, 0]
        for j in stop_append:
            if not stop_append[j]:
                if i+j-1 < l:
                    y = data_1[i+j-1,0]
                    y = y.reshape(-1,1)
                    x_1 = x_1.reshape(-1,1)
                    x_2 = x_2.reshape(-1,1)
                    
                    sc = MinMaxScaler(feature_range=(0,1))
                    sc.partial_fit(x_1)
                    sc.partial_fit(y)
                    scaler[s][j].append(sc)
                    test_set[s]['x_1'][j].append(sc.transform(x_1))
                    test_set[s]['y'][j].append(y)
                    sc = MinMaxScaler(feature_range=(0,1))
                    test_set[s]['x_2'][j].append(sc.fit_transform(x_2))
                    
                    if y == data_1[l-1,0]:
                        stop_append[j] =True
                    
    return test_set, scaler

# %%
def make_prediction(data, s, scaler):
    mse_val = {}
    y_true_val = {}
    y_pred_val = {}
    
    for i in prediction_intervals:
        x_test = []
        for j in range (0, len(data[s]['x_1'][i])):
            x = [
                data[s]['x_1'][i][j],
                data[s]['x_2'][i][j],
            ]
            x_test.append(x)

        X_test = np.array(x_test)
        X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], X_test.shape[2])
        
        result = model[i].predict(X_test)
        y_pred = []
        for j in range(0,len(result)):
            y = result[j]
            y = y.reshape(-1,1)
            k = scaler[s][i][j].inverse_transform(y)
            y_pred.append(k[0][0])
                    
        y_test = data[s]['y'][i]
        y_true = np.array(y_test)
        y_true = y_true.reshape(y_true.shape[0])
    
        y_true_val[i] = y_true
        y_pred_val[i] = y_pred

        mse_val[i] = return_mse(y_true, y_pred) 
    return y_true_val, y_pred_val, mse_val

# %%
s = 'AAPL'
data, sc = make_test_data(s)
y_true_val, y_pred_val, mse_val = make_prediction(data, s, sc)

for i in mse_val:
    print('Test Set -> MSE of {} inveral {}: {}'.format(s, i, mse_val[i]))
# Out:
# Test Set -> MSE of AAPL inveral 1: 8.58164841415352
# Test Set -> MSE of AAPL inveral 3: 25.485500045438584
# Test Set -> MSE of AAPL inveral 5: 50.37156712019173
# Test Set -> MSE of AAPL inveral 10: 94.70282818379012

# %%
for i in [1,10]:
    plotting_graph(y_true_val[i], y_pred_val[i], s, 'Test Set interval {}'.format(i))

# %% [markdown]
# # MSE of 10 symbols

# %%
test_symbols = ['A','AAPL','ABAX','ACIU','ADUS']

# %%
all_mse = {}
for s in test_symbols:
    all_mse[s] = {}
    data, sc = make_test_data(s)
    y_true_val, y_pred_val, mse_val = make_prediction(data, s, sc)
    for i in prediction_intervals:
        all_mse[s][i] = mse_val[i]
        all_mse[s][i] = mse_val[i]

# %%
all_mse_1 = []
all_mse_10 = []
for s in all_mse:
    all_mse_1.append(round(all_mse[s][1], 3))
    all_mse_10.append(round(all_mse[s][10], 3))

# %%
all_mse_1
# Out:
# [1.724, 8.582, 4.373, 1.348, 2.021]

# %%
all_mse_10
# Out:
# [3.8, 94.703, 27.576, 4.986, 16.539]

# %%
for i in range(0, len(all_mse_1)):
    print('MSE of Interval 10 = {} Interval 1'.format(round(all_mse_10[i]/all_mse_1[i], 1)))
# Out:
# MSE of Interval 10 = 2.2 Interval 1
# MSE of Interval 10 = 11.0 Interval 1
# MSE of Interval 10 = 6.3 Interval 1
# MSE of Interval 10 = 3.7 Interval 1
# MSE of Interval 10 = 8.2 Interval 1
